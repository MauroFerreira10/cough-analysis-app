# %% [markdown]
# # 🫁 Análise de Tosse com Machine Learning
#
# ## Detecção de Pneumonia e Bronquite usando Deep Learning
#
# Este notebook permite executar o projeto completo no Google Colab.
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/MauroFerreira10/cough-analysis-app/blob/main/Colab_Training.ipynb)
#
# ---

# %% [markdown]
# ## 📦 1. Setup Inicial
#
# Clone o repositório e instale dependências:

# %%
# Clone o repositório (SUBSTITUA com sua URL do GitHub)
# !git clone https://github.com/MauroFerreira10/cough-analysis-app.git
# %cd cough-analysis-app

# Instale dependências
# !pip install -q librosa soundfile matplotlib scipy scikit-learn tensorflow pandas tqdm pyyaml noisereduce

# %%
# Verifique instalação
import numpy as np
import librosa
import tensorflow as tf

print(f"✅ NumPy: {np.__version__}")
print(f"✅ Librosa: {librosa.__version__}")
print(f"✅ TensorFlow: {tf.__version__}")
print(f"✅ GPU disponível: {len(tf.config.list_physical_devices('GPU')) > 0}")
