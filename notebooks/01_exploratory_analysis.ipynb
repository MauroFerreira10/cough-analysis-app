# %% [markdown]
# # Análise Exploratória de Dados de Tosse
#
# Este notebook demonstra como explorar e visualizar dados de áudio de tosse.

# %%
import sys
sys.path.append('..')

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import librosa
import librosa.display

from src.utils.audio_utils import load_audio, normalize_audio
from src.utils.visualization import plot_waveform, plot_mel_spectrogram, plot_mfcc

# %matplotlib inline
sns.set_style('whitegrid')
